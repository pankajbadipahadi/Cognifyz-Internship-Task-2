# %% [markdown]
# ## **Level 1 Task 1 Top Cuisines**

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Dataset .csv')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# ### **1) Determine the top 3 most common cuisines in the dataset**

# %%
df['Cuisines'].value_counts().head(3)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %% [markdown]
# ### **2) Calculate the percentage of restaurants that serve each of the top cuisines.**

# %%
cui_count=df['Cuisines'].value_counts()
cuisine_percentage = (cui_count / len(df)) * 100
cui_percentage_df = cuisine_percentage.reset_index()
cui_percentage_df.columns = ['Cuisine', 'Restaurant_Percentage']
print(cui_percentage_df.head(10))
# Out:
#                           Cuisine  Restaurant_Percentage
# 0                    North Indian               9.800021
# 1           North Indian, Chinese               5.350225
# 2                         Chinese               3.706418
# 3                       Fast Food               3.706418
# 4           North Indian, Mughlai               3.497016
# 5                            Cafe               3.130562
# 6                          Bakery               2.282484
# 7  North Indian, Mughlai, Chinese               2.062611
# 8                Bakery, Desserts               1.779918
# 9                     Street Food               1.560046

# %% [markdown]
# ## **Level 1 Task 2 City Analysis**

# %% [markdown]
# **1) Identify the city with the highest number of restaurants in the dataset**

# %%
df['City'].value_counts()
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %% [markdown]
# **2) Calculate the average rating for restaurant in each city**

# %%
df.groupby('City')['Aggregate rating'].mean()
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ��stanbul          4.292857
# Name: Aggregate rating, Length: 141, dtype: float64

# %% [markdown]
# ### **3) Determine the city with the highest average rating**

# %%
df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).head(1)
# Out:
# City
# Inner City    4.9
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# # **Level 1 Task 3 Price Range Distribution**

# %% [markdown]
# **1) Create a histogram or bar chart to visualize the distribution of price ranges among the restairants.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df['Price range'].value_counts().plot(kind='bar',color='purple')
plt.xlabel('Price Range')
plt.ylabel('Restaurant Count')
plt.title('Distribution of price range among restaurants')
plt.show()

# %% [markdown]
# **2) Calculate the percentage of restaurants in each price range category**

# %%
price_range=df['Price range'].value_counts()
price_range_percentage=(price_range/len(df))*100
price_range_percentage_df=price_range_percentage.reset_index()
price_range_percentage_df.columns=['Price Range','Restaurant_Percentage']
print(price_range_percentage_df.head(10))
# Out:
#    Price Range  Restaurant_Percentage
# 0            1              46.529159
# 1            2              32.593446
# 2            3              14.741912
# 3            4               6.135483

# %% [markdown]
# # **Level 1 Task 4 Online Delivery**

# %% [markdown]
# **1) Determine the percentage of restaurants that offer online delivery**

# %%
online_count=df['Has Online delivery'].value_counts()
restaurant_percent=(online_count/len(df))*100
print("Percentage of restaurant that offer onine delivery is ",restaurant_percent[1],round(2))
# Out:
# Percentage of restaurant that offer onine delivery is  25.662234321013504 2
# /tmp/ipython-input-42-2013618214.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("Percentage of restaurant that offer onine delivery is ",restaurant_percent[1],round(2))

# %% [markdown]
# **2) Compare the average rating of restaurants with and without online delivery**

# %%
average=df.groupby('Has Online delivery')['Aggregate rating'].mean()
print(average)
# Out:
# Has Online delivery
# No     2.465296
# Yes    3.248837
# Name: Aggregate rating, dtype: float64
